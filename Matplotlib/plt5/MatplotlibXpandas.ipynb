# %%
# --- create data frame ---
import pandas as pd

data ={
    "Month":["Jan","Feb","Mar","Apr","May"],
    "Sales":[120,150,180,145,210],
    "Expenses":[80,90,100,80,110]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Month  Sales  Expenses
# 0   Jan    120        80
# 1   Feb    150        90
# 2   Mar    180       100
# 3   Apr    145        80
# 4   May    210       110

# %%
# --- ploting data frame ---
import matplotlib.pyplot as plt

df.plot(
    x="Month",
    y="Sales",
    kind="line" # 'line', 'bar', 'pie'
)
plt.title("Monthly Sales Line Chart")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
# --- compare Sales and Expenses ---

df.plot(
    x="Month",
    y=["Sales","Expenses"],
    kind="bar"
)
plt.title("sales vs expenses")
plt.xlabel("Month")
plt.ylabel("Amount")
plt.xticks(rotation=0)

plt.show()

# %%
# --- create a histogram ---

df["Sales"].plot(
    kind="hist",
    bins=5
)
plt.title("sales distribution")
plt.xlabel("Sales")
# Out:
# Text(0.5, 0, 'Sales')

# %%
# --- groupby & visualization ---
import pandas as pd2

data = {
    "Departement":[
        "Sales","sales",
        "IT","IT",
        "HR","HR"
    ],
    "Revenue":[
        100,150,
        200,180,
        80,90
    ]
}
df2 = pd2.DataFrame(data)
summary = df2.groupby("Departement")["Revenue"].sum()

print(summary)

summary.plot(kind="bar")
plt.title("Revenue by Departement")
plt.xlabel("Departement")
plt.ylabel("Revenue")
plt.xticks(rotation=0)

plt.show()
# Out:
# Departement
# HR       170
# IT       380
# Sales    100
# sales    150
# Name: Revenue, dtype: int64

# %%
# --- time series visualization ---
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Date":[
        "2026-01-01",
        "2026-02-01",
        "2026-03-01",
        "2026-04-01"
    ],
    "Sales":[100,120,160,145]
}

df = pd.DataFrame(data)

df["Date"] = pd.to_datetime(df["Date"])

df.plot(
    x="Date",
    y="Sales",
    kind="line"
)

plt.title("Sales Trend")
plt.xlabel("Date")
plt.ylabel("sales")

plt.show()
